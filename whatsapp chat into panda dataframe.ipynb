# %%
import pandas as pd
import datetime
import numpy
import re

# %%
def startsWithDateAndTime(s):
    # regex pattern for date.(Works only for android. IOS Whatsapp export format is different. Will update the code soon
    pattern = '^([0-9]+)(\/)([0-9]+)(\/)([0-9][0-9]), ([0-9]+):([0-9][0-9]) (AM|PM) -'
    result = re.match(pattern, s)
    if result:
        return True
    return False
  
# Finds username of any given format.
def FindAuthor(s):
    patterns = [
        '([\w]+):',                        # First Name
        '([\w]+[\s]+[\w]+):',              # First Name + Last Name
        '([\w]+[\s]+[\w]+[\s]+[\w]+):',    # First Name + Middle Name + Last Name
        '([+]\d{2} \d{5} \d{5}):',         # Mobile Number (India)
        '([+]\d{2} \d{3} \d{3} \d{4}):',   # Mobile Number (US)
        '([\w]+)[\u263a-\U0001f999]+:',    # Name and Emoji              
    ]
    pattern = '^' + '|'.join(patterns)
    result = re.match(pattern, s)
    if result:
        return True
    return False
  
def getDataPoint(line):   
    splitLine = line.split(' - ') 
    dateTime = splitLine[0]
    date, time = dateTime.split(', ') 
    message = ' '.join(splitLine[1:])
    if FindAuthor(message): 
        splitMessage = message.split(': ') 
        author = splitMessage[0] 
        message = ' '.join(splitMessage[1:])
    else:
        author = None
    return date, time, author, message

parsedData = [] # List to keep track of data so it can be used by a Pandas dataframe
# Upload your file here
conversationPath = 'fychat.txt' # chat file
with open(conversationPath, encoding="utf-8") as fp:
    fp.readline() # Skipping first line of the file because contains information related to something about end-to-end encryption
    messageBuffer = [] 
    date, time, author = None, None, None
    while True:
        line = fp.readline() 
        if not line: 
            break
        line = line.strip() 
        if startsWithDateAndTime(line): 
            if len(messageBuffer) > 0: 
                parsedData.append([date, time, author, ' '.join(messageBuffer)]) 
            messageBuffer.clear() 
            date, time, author, message = getDataPoint(line) 
            messageBuffer.append(message) 
        else:
            messageBuffer.append(line)
   
df = pd.DataFrame(parsedData, columns=['Date', 'Time', 'Author', 'Message']) # Initialising a pandas Dataframe.
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.head()
# Out:
#         Date     Time       Author  \
# 0 2020-02-12  6:32 PM         None
# 1 2020-02-12  6:32 PM         None
# 2 2020-02-12  6:33 PM         None
# 3 2020-02-12  6:35 PM  swapnil sir
# 4 2020-02-12  6:36 PM  swapnil sir
#
#                                              Message
# 0       swapnil sir created group "Freshers Cytron "
# 1                              swapnil sir added you
# 2              swapnil sir changed this group's icon
# 3  This group is for first year members. I'm prov...
# 4  Arpit add everyone from first year except pce ...

# %%
df.dropna()
# Out:
#           Date      Time           Author  \
# 3   2020-02-12   6:35 PM      swapnil sir
# 4   2020-02-12   6:36 PM      swapnil sir
# 21  2020-02-12   8:25 PM  +91 90799 06440
# 22  2020-02-12   8:28 PM           Bhavya
# 23  2020-02-18   1:31 PM      swapnil sir
# 25  2020-03-03   3:42 PM           Bhavya
# 27  2020-03-09   3:03 PM           Bhavya
# 116 2020-08-29   3:30 PM  +91 89490 90660
# 117 2020-08-29   5:44 PM  +91 95218 44845
#
#                                                Message
# 3    This group is for first year members. I'm prov...
# 4    Arpit add everyone from first year except pce ...
# 21   Welcome to Cytron Club Hello guys.. Kashish th...
# 22   Bhavya here from 2nd year..  Congratulations, ...
# 23   https://instagram.com/stories/we.cytron/224640...
# 25   Hello guys!! Swapnil has left the group bcoz o...
# 27   Re-discover Peace and Happiness. Celebrate. ht...
# 30   Announcing our website upgrade take a tour and...
# 31                Prefer laptop for better experience😅
# 32   Sir I am from E section (pgi) There is no E se...
# 33                                             Wait !!
# 34                         After some time try again!!
# 35                                            Okay sir
# 36                      Issue solved. Check again now.
# 37                        First year session 2019 2023
# 38                                    Choose correctly
# 39   Sir pta ni kyu registration no. Invalid dikha ...
# 40                                      Piet or pgi ??
# 41                                            Sir piet
# 42                                                Piet
# 43                                                  Ok
# 44                                        Now it won't
# 45                                      Just try again
# 46                                   Sir avi v prblm h
# 47                                                Same
# 48                                             Yes sir
# 49                                             Yes sir
# 50                                   Screenshot bhejna
# 51                                             Okk sir
# 52                                     <Media omitted>
# ..                                                 ...
# 78                                     Thank you bhaii
# 81   https://www.instagram.com/p/B_-fPt3ASPQ/?igshi...
# 82                                            Try this
# 84   I recently developed and deployed a Weather We...
# 85                                                   👌
# 86                                                  🤟🤟
# 87   https://www.instagram.com/tv/CCd5E2PHbV2/?igsh...
# 88                                              😂😂😂😂😂😂
# 89                            This message was deleted
# 90   https://datahack.analyticsvidhya.com/contest/j...
# 92   Must Read.  https://blog.tensorflow.org/2020/0...
# 93                                       Interesting🤟🏻
# 94                                                  👍🏼
# 95                                                  👍🏽
# 96   He who himself opened the OpenAI Lab  https://...
# 97   Open-source low level code ML library for Pyth...
# 98                https://www.daviddunphy.co.uk/snake/
# 99   Check out this project, give it a try on runni...
# 100                                      Amazing stuff
# 101  http://monalisaeffect.com  Legends say Mona Li...
# 102  https://css-tricks.com/halfmoon-a-bootstrap-al...
# 103  https://gadgets.ndtv.com/internet/news/google-...
# 105                                    <Media omitted>
# 106            https://covid19challenge.mit.edu/india/
# 107    An amazing opportunity to get exposure from MIT
# 111  VR Virtual Convocation Ceremony 👌🏼  https://ww...
# 114  Hello everyone! We have taken a part in MITCov...
# 115  I hope you all are doing well. Practice the co...
# 116                                                 🙌🏼
# 117                                                 🤝🏻
#
# [79 rows x 4 columns]

# %%
df.Author.unique()
# Out:
# array([None, 'swapnil sir', '+91 90799 06440', 'Bhavya', 'Shashank Tak',
#        '+91 86192 39406', '+91 95880 57797', '+91 73219 48250',
#        '+91 89490 90660', '+91 820 985 1728', '+91 74248 98333',
#        '+91 95115 17886', '+91 76270 26366', '+91 95218 44845'],
#       dtype=object)
